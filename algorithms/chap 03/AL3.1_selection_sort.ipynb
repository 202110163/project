# %% [markdown]
# ## 01. 문제 정의
# 리스트 n개의 항목들이 들어 있다. 이들을 키(KEY)의 순서에 때라 오름차순으로 재배치하는 문제

# %% [markdown]
# ## 02.알고리즘 설명
# 0~n-2의 for 외부루트 설정
# i+1 ~ n-2의 for 내부루트 설정
# j< least 보다 작으면 j를 lesat에 최소값 저장

# %% [markdown]
# ## 03. 손으로 푼 예제
# ![KakaoTalk_20240416_203108728.jpg](attachment:KakaoTalk_20240416_203108728.jpg)

# %% [markdown]
# ## 04. 코드 개요
# def selection(A): 선택정렬 함수 설정하고 리스트 A의 길이만큼 n에 저장 for 외부루트 (0~n-2)만큼 for 내부루트 (i+1... n-1)까지 i 이후의 모든 항목에서 작은항목 lesat를 계산하고 i번째 least 항목을 서로 교환

# %% [markdown]
# ## 5. 코드

# %%
def printstep(arr, val):
    print(" step %2d = " % val, end='')
    print(arr)

def selection(A):
    n=len(A)
    for i in range(n-1):
        least =i
        for j in range(i+1, n):
            if(A[j]<A[least]):
                least =j
        A[i], A[least] = A[least], A[i]
        printstep(A, i+1)

data = [5,3,8,4,9,1,6,2,7]
print("original", data)
selection(data)
print("selection : ",data)

# %% [markdown]
# ## 06. 테스트 코드, 입력을 바꿔서

# %% [markdown]
# def printstep(arr, val):
#     print(" step %2d = " % val, end='')
#     print(arr)
#
# def selection(A):
#     n=len(A)
#     for i in range(n-1):
#         least =i
#         for j in range(i+1, n):
#             if(A[j]<A[least]):
#                 least =j
#         A[i], A[least] = A[least], A[i]
#         printstep(A, i+1)
#
# data = [7,1,8,4,10,1,16,2,17]
# print("original", data)
# selection(data)
# print("selection : ",data)
#
# original [7, 1, 8, 4, 10, 1, 16, 2, 17]
#  step  1 = [1, 7, 8, 4, 10, 1, 16, 2, 17]
#  step  2 = [1, 1, 8, 4, 10, 7, 16, 2, 17]
#  step  3 = [1, 1, 2, 4, 10, 7, 16, 8, 17]
#  step  4 = [1, 1, 2, 4, 10, 7, 16, 8, 17]
#  step  5 = [1, 1, 2, 4, 7, 10, 16, 8, 17]
#  step  6 = [1, 1, 2, 4, 7, 8, 16, 10, 17]
#  step  7 = [1, 1, 2, 4, 7, 8, 10, 16, 17]
#  step  8 = [1, 1, 2, 4, 7, 8, 10, 16, 17]
# selection :  [1, 1, 2, 4, 7, 8, 10, 16, 17]

# %% [markdown]
# ## 07.수행 결과

# %% [markdown]
# original [5, 3, 8, 4, 9, 1, 6, 2, 7]
#  step  1 = [1, 3, 8, 4, 9, 5, 6, 2, 7]
#  step  2 = [1, 2, 8, 4, 9, 5, 6, 3, 7]
#  step  3 = [1, 2, 3, 4, 9, 5, 6, 8, 7]
#  step  4 = [1, 2, 3, 4, 9, 5, 6, 8, 7]
#  step  5 = [1, 2, 3, 4, 5, 9, 6, 8, 7]
#  step  6 = [1, 2, 3, 4, 5, 6, 9, 8, 7]
#  step  7 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
#  step  8 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# selection :  [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ## 08. 복잡도 분석
# O(n2)

# %% [markdown]
# ## 09. 조별 협력 내용
# 모르는 부분이 있으면 팀원과 함께 문제를 해결했습니다
